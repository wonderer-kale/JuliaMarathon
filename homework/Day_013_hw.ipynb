# %% [markdown]
# ## Day 013 作業1：用 Julia 標準函式寫 Sigmoid Function
#
# 在 Day 002 時我們曾用 LaTeX 撰寫機器學習常見的激活函式 Sigmoid
#
# $\Large f(x)=\frac{1}{1+e^{-x}}$
#
# 作業 1 請使用內建函式 `exp()` 來撰寫 Sigmoid 函式，計算矩陣的 sigmoid 值。

# %% [markdown]
# 例如：數字 3 的 sigmoid 值。

# %%
1 / (1 + exp(-3))
# Out:
# 0.9525741268224334

# %% [markdown]
# 宣告及建立矩陣

# %%
A = Matrix([1 10 3 4 6; 4 2 4 5 10; 8 5 3 5 9])
# Out:
# 3×5 Array{Int64,2}:
#  1  10  3  4   6
#  4   2  4  5  10
#  8   5  3  5   9

# %%
# 請在此撰寫計算 sigmoid
sigmoidA = rand(0:1.0, 3, 5)
for i in A
    sigmoidA[i] = 1 / (1 + exp(-A[i]))
end
sigmoidA
# Out:
# 3×5 Array{Float64,2}:
#  0.731059  0.999955  1.0       0.982014  1.0
#  0.982014  0.880797  0.982014  1.0       1.0
#  0.999665  0.993307  0.952574  0.0       0.0

# %% [markdown]
# ## 作業2：線性代數基礎運算 Matrix Multiplication 及 Addition
#
# 假設 A 是 $n\times m$ 的矩陣，B 是 $m\times p$ 的矩陣，則矩陣乘法的積 AB 是 $\displaystyle n\times p$ 的矩陣。
#
# 作業2 請撰寫程式，隨機產生矩陣 $W$ 及 $X$，計算線性方程式 $WX+b$。
#
# 【提示】點運算的介紹，可回顧 Day 005 內容及範例。

# %%
# 給定 bias 變數值
# 這邊給定的是純量，在矩陣加法中透過 broadcasting 進行加法
b = 1
n = rand(1:5000)
m = rand(1:5000)
p = rand(1:5000)
# Out:
# 862

# %%
w = rand(n, m)
# Out:
# 144×2356 Array{Float64,2}:
#  0.820266    0.663363   0.969659   …  0.3176     0.273265   0.446369
#  0.189302    0.926947   0.784523      0.733442   0.559408   0.0555122
#  0.0887116   0.771295   0.53485       0.251632   0.53548    0.553198
#  0.588528    0.335064   0.133343      0.154973   0.398264   0.833378
#  0.638721    0.209646   0.14291       0.193262   0.535386   0.312901
#  0.545845    0.308287   0.631947   …  0.89288    0.537555   0.700776
#  0.683782    0.938087   0.520174      0.686305   0.50418    0.780776
#  0.288789    0.509056   0.546722      0.845799   0.743686   0.245612
#  0.312918    0.268942   0.95914       0.667144   0.801756   0.0921975
#  0.427058    0.398775   0.996162      0.892058   0.617192   0.706113
#  0.0413365   0.441355   0.534866   …  0.56728    0.0888721  0.472253
#  0.360374    0.100736   0.421324      0.455086   0.175065   0.54024
#  0.00277653  0.375043   0.456504      0.932784   0.517772   0.694819
#  ⋮                                 ⋱                        ⋮
#  0.232862    0.137626   0.407         0.431809   0.0723337  0.834871
#  0.587389    0.39663    0.78417       0.311023   0.801963   0.0450353
#  0.968124    0.672244   0.362321      0.122075   0.945441   0.852749
#  0.547065    0.0457549  0.443955   …  0.112296   0.356748   0.0962878
#  0.872056    0.860135   0.370041      0.850936   0.0268982  0.679066
#  0.315524    0.677612   0.903409      0.521394   0.632176   0.883235
#  0.199566    0.564284   0.847136      0.338656   0.234008   0.581006
#  0.890351    0.655884   0.423468      0.0555172  0.0966514  0.811196
#  0.0747043   0.234632   0.0222431  …  0.0161808  0.162869   0.161204
#  0.488644    0.22933    0.938527      0.1668     0.96189    0.904553
#  0.282551    0.766549   0.465972      0.0958079  0.242344   0.586917
#  0.011219    0.492296   0.980838      0.43386    0.821347   0.526458

# %%
X = rand(m, p)
# Out:
# 2356×862 Array{Float64,2}:
